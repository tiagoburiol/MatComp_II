# %% [markdown]
# ## 9. Funções Vetoriais e Curvas Espaciais
#
# Uma função vetorial, ou função com valores vetoriais, é uma função cujo domínio é um conjunto de números reais e cuja imagem é um conjunto de vetores ([Stewart, 2022](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/301)).
#
# Para funções vetoriais $\mathbf{r}$ cujos valores são vetores tridimensionais, para todo número $t$ no domínio de $\mathbf{r}$ existe um único vetor de $V_3$ denotado por $\mathbf{r}(t)$. Se $f(t), g(t)$ e $h(t)$ são as componentes do vetor $\mathbf{r}(t)$, então $f, g$ e $h$ são funções com valores reais chamadas funções. Denotamos por
#
# $$
# \mathbf{r}(t)=\langle f(t), g(t), h(t)\rangle=f(t) \mathbf{i}+g(t) \mathbf{j}+h(t) \mathbf{k}
# $$

# %% [markdown]
# As curvas espaciais e as funções vetoriais contínuas estão intimamente relacionadas. Suponha que $f, g$ e $h$ sejam funções reais contínuas em um intervalo $I$. Em seguida, o conjunto $C$ de todos os pontos $(x, y, z)$ no espaço, sendo
#
# $$
# x=f(t) \quad y=g(t) \quad z=h(t)
# $$
#
# e $t$ varia no intervalo $I$, é chamado **curva espacial**. As equações acima são denominadas equações paramétricas de $C$ e $t$ é conhecido como parâmetro.

# %% [markdown]
# ### 9.1 Plotando funções vetoriais e paramétricas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#%matplotlib qt
#%matplotlib notebook 
#%matplotlib widget
#%matplotlib ipympl
#%matplotlib tk
# %matplotlib inline

# %% [markdown]
# **Exemplo 9.1:** Vamos representar a reta definida pela função vetorial
#
# $$
# \mathbf{r}(t)=\langle 1+t, 2+5 t,-1+6 t\rangle
# $$

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.linspace(0, 5)

ax.plot(1+t, 2+5*t, -1 + 6*t)
plt.show()

# %% [markdown]
# **Exemplo 9.2:** Agora, vamos representar a curva definida pela função vetorial
#
# $$
# \mathbf{r}(t)=\cos t \mathbf{i}+\operatorname{sen} t \mathbf{j}+t \mathbf{k}
# $$

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.linspace(0, 8*np.pi,200)

ax.plot(np.cos(t), np.sin(t), t)
plt.show()

# %% [markdown]
# **Exemplo 9.3:** ([Stewart, 2022, p. 824](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/303)) Determine uma equação vetorial que represente a curva obtida pela intersecção do cilindro $x^2+y^2=1$ com o plano $y+z=2$.

# %% [markdown]
# Podemos escrever as equações paramétricas para $C$ como
#
# $$
# x=\cos t \quad y=\operatorname{sen} t \quad z=2-\operatorname{sen} t \quad 0 \leq t \leq 2 \pi
# $$
#
# então, a equação vetorial correspondente é
#
# $$\mathbf{r}(t)=\cos t \mathbf{i}+\operatorname{sen} t \mathbf{j}+(2-\operatorname{sen} t) \mathbf{k} \quad 0 \leq t \leq 2 \pi$$

# %%
#cria a figura
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

# cilindro - coordenadas cilindricas
t,z = np.meshgrid(np.linspace(0,2*np.pi,36), np.linspace(0,5,20))
x = np.cos(t)
y = np.sin(t)
ax.plot_wireframe(x, y, z, lw=0.2, color='k')

# plano
x,y = np.meshgrid(np.linspace(-1,1,20), np.linspace(-1,1,20))
z = 2-y
ax.plot_wireframe(x, y, z, lw=0.2, color='k')

t = np.linspace(0,2*np.pi,36)
x = np.cos(t)
y = np.sin(t)
z = 2-np.sin(t)
ax.plot(x, y, z, lw=1, color='r')

# %% [markdown]
# **Exemplo 9.4:** ([Stewart, 2022, p. 825](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/303)) Determine as equações paramétricas da curva formada pela intersecção do paraboloide $4 y=x^2+z^2$ com o plano $y=x$.
#
# *SOLUÇÃO:* Como qualquer ponto da curva $C$, que está na intersecção das superfícies, satisfaz as equações das duas superfícies, podemos substituir $y=x$ na equação do paraboloide, o que nos fornece $4 x=x^2+z^2$. Completando o quadrado em $x$, obtemos $(x-2)^2+$ $z^2=4$, de modo que $C$ deve estar contida no cilindro circular $(x-2)^2+z^2=4$ e a projeção de $C$ no plano $x z$ será a circunferência definida por $(x-2)^2+z^2=4, y=0$, que tem centro em $(2,0,0)$ e raio 2. Assim, podemos escrever $x=2+2 \cos t$, $z=2 \operatorname{sen} t, 0 \leq t \leq 2 \pi$, e, uma vez que $y=x$, as equações paramétricas de $C$ são
#
# $$
# x=2+2 \cos t, \quad y=2+2 \cos t, \quad z=2 \operatorname{sen} t, \quad 0 \leq t \leq 2 \pi
# $$

# %%
#%matplotlib tk
# %matplotlib inline

# %%
#cria a figura
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

# paraboloide
t = np.linspace(0, 2*np.pi, 37)
r = np.linspace(0, 5)
rv, tv = np.meshgrid(r, t)

x = rv*np.cos(tv)
z = rv*np.sin(tv)
y = x**2/4 + z**2/4

#ax.plot_surface(x, y, z, alpha=0.5)
ax.plot_wireframe(x, y, z, lw=0.2, color='k')

# plano
x = np.linspace(0,5,21)
y = x.copy()
z = np.repeat(np.array([np.linspace(-5,5,11)]), len(x), axis=0).T

#ax.plot_surface(x, y, z, alpha=0.5)
ax.plot_wireframe(x, y, z, lw=0.2, color='k')

# curva
t = np.linspace(0, 2*np.pi, 37)

x = 2+2*np.cos(t)
y = 2+2*np.cos(t)
z = 2*np.sin(t)

ax.plot(x, y, z, lw=1, color='r')


ax.set_box_aspect([1,1,1])
plt.show()

# %% [markdown]
# **Exemplo 9.5:** Plotando uma [espiral toroidal](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/304), cujas equações paramétricas são dadas por
#
# $$
# x=(4+\operatorname{sen} 20 t) \cos t \quad y=(4+\operatorname{sen} 20 t) \operatorname{sen} t \quad z=\cos 20 t
# $$

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.linspace(0, 2*np.pi,500)

x = (4+np.sin(20*t))*np.cos(t)
y = (4+np.sin(20*t))*np.sin(t)
z = np.cos(20*t)

ax.plot(x,y,z)

ax.set_box_aspect([1,1,0.25]) # proporção dos eixos
plt.show()

# %% [markdown]
# **Exemplo 9.5:** Plotando uma [nó de trevo ou trifólio](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/304), cujas equações paramétricas são dadas por
#
# $$
# x=(2+\cos 1,5 t) \cos t \quad y=(2+\cos 1,5 t) \operatorname{sen} t \quad z=\operatorname{sen} 1,5 t
# $$

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.linspace(0, 20, 500)

x = (2+np.cos(1.5*t))*np.cos(t)
y = (2+np.cos(1.5*t))*np.sin(t)
z = np.sin(1.5*t)

ax.plot(x,y,z)
ax.set_box_aspect([1,1,0.5]) # proporção dos eixos
plt.show()

# %% [markdown]
# **Exemplo 9.6:** Plotando a curva com equação vetorial $\mathbf{r}(t)=\left\langle t, t^2, t^3\right\rangle$. Essa curva é chamada [cúbica retorcida](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/304).

# %%
#%matplotlib tk
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

t = np.linspace(-2, 2)

x = t
y = t**2
z = t**3

ax.plot(x,y,z)
ax.set_box_aspect([1,1,0.5]) # proporção dos eixos
plt.show()

# %% [markdown]
# **Comprimento de uma Curva**
#
# Se $C$ é a curva representada por $\mathbf{r}(t)$ com derivada contínua $\mathbf{r}^{\prime}(t)$ em $a \leq t \leq b$, dizemos que o comprimento $l$ de $C$ é
#
# $$
# I=\int_a^b \sqrt{\mathbf{r}^{\prime} \cdot \mathbf{r}^{\prime}} d t
# $$

# %% [markdown]
# **Exemplo 9.7:** O comprimento da hélice circular $\mathbf{r}(t)=\langle 2 \cos t, 2 \operatorname{sen} t, 6 t \rangle$ de $(2,0,0)$ a $(2,0$, $24 \pi)$ pode ser calculado fazendo:

# %%
import sympy as sp
from sympy import sin, cos, pi, exp

# %%
t = sp.symbols('t')

# %%
r = sp.Matrix([2*cos(t),2*sin(t),6*t])
sp.solve(sp.Eq(r, sp.Matrix([2,0,0])))
# Out:
# [{t: 0}]

# %%
sp.solve(sp.Eq(r, sp.Matrix([2,0,24*pi])))
# Out:
# [{t: 4*pi}]

# %%
norm_dr = sp.sqrt(r.diff(t).dot(r.diff(t)))
display(norm_dr)
# Out:
# sqrt(4*sin(t)**2 + 4*cos(t)**2 + 36)

# %%
sp.trigsimp(norm_dr)
# Out:
# 2*sqrt(10)

# %%
sp.integrate(norm_dr, (t,0,4*pi))
# Out:
# 8*sqrt(10)*pi

# %% [markdown]
# ### 9.2 Plotando campos vetoriais
#
# ([Stewart, 2016](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/518)) Seja $D$ um conjunto em $\mathbb{R}^2$ (uma região plana). Um campo vetorial em $\mathbb{R}^2$ é uma função $\mathbf{F}$ que associa a cada ponto $(x, y)$ em $D$ um vetor bidimensional $\mathbf{F}(x, y)$.
#
# Uma vez que $\mathbf{F}(x, y)$ é um vetor bidimensional, podemos escrevê-lo em termos de suas funções componentes $P$ e $Q$ da seguinte forma:
#
# $$
# \mathbf{F}(x, y)=P(x, y) \mathbf{i}+Q(x, y) \mathbf{j}=\langle P(x, y), Q(x, y)\rangle
# $$
#
# ou, de forma mais compacta,
#
# $$
# \mathbf{F}=P \mathbf{i}+Q \mathbf{j}
# $$
#
#
# Observe que $P$ e $Q$ são funções escalares de duas variáveis e são chamadas, algumas vezes, campos escalares, para distingui-los dos campos vetoriais.

# %% [markdown]
# **Exemplo 9.8:**
# Nesse exemplo vamos representar graficamente o campo de vetores dados pela função $$f(x,y)=\left(\frac{-y^2}{x^4+y^4},\frac{x}{\sqrt{x^2+y^2}} \right)$$
#
# usando uma malha de 10x10 pontos, com $-5 \leq x \leq 5$ e $-5 \leq y \leq 5$.

# %%
fig = plt.figure(figsize=(4,3))
x = np.linspace(-5,5,10)
y = np.linspace(-5,5,10)
xi,yi = np.meshgrid(x,y)

u = -yi**2/np.sqrt(xi**4 + yi**4)
v = xi/np.sqrt(xi**2 + yi**2)

#plt.streamplot(xi,yi,u,v)

plt.quiver(xi,yi,u,v)
plt.show()

# %% [markdown]
# Seja $E$ um subconjunto de $\mathbb{R}^3$. Um campo vetorial em $\mathbb{R}^3$ é uma função $\mathbf{F}$ que associa a cada ponto $(x, y, z)$ em $E$ um vetor tridimensional $\mathbf{F}(x, y, z)$.
#
# Podemos escrever um campo vetorial $\mathbf{F}$ em $\mathbb{R}^3$ em termos das funções componentes $P, Q$ e $R$ como
#
# $$
# \mathbf{F}(x, y, z)=P(x, y, z) \mathbf{i}+Q(x, y, z) \mathbf{j}+R(x, y, z) \mathbf{k}
# $$

# %% [markdown]
# **Exemplo 9.9
# :** Nesse exemplo vamos representar graficamente o campo de vetores dados pela função $$f(x,y,z)=\left( sen(x)cos(yz),-yz, cos(x)sen(z) \right)$$
#
# usando uma malha de 10x10 pontos, com $-5 \leq x \leq 5$ e $-5 \leq y \leq 5$.

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')

x,y,z = np.meshgrid(np.arange(-1, 1, 0.25),
                    np.arange(-1, 1, 0.25),
                    np.arange(-1, 1, 0.25))

u = np.sin(x) * np.cos(y*z)
v = -y*z
w = np.cos(x) * np.sin(z)

ax.quiver(x, y, z, u, v, w, 
          length=0.2, linewidths= 0.7,
          color = 'black')

plt.show()

# %% [markdown]
# ### 9.3 Campo gradiente
# Se $f$ é uma função escalar de duas variáveis, seu gradiente $\nabla f$ (ou $\operatorname{grad} f$ ) é definido por
#
# $$
# \nabla f(x, y)=f_x(x, y) \mathbf{i}+f_y(x, y) \mathbf{j}
# $$
#
# Portanto, $\nabla f$ é realmente um campo vetorial em $\mathbb{R}^2$ e é denominado campo vetorial gradiente. Da mesma forma, se $f$ for uma função escalar de três variáveis, seu gradiente é um campo vetorial em $\mathbb{R}^3$ dado por
#
# $$
# \nabla f(x, y, z)=f x(x, y, z) \mathbf{i}+f y(x, y, z) \mathbf{j}+f z(x, y, z) \mathbf{k}
# $$

# %% [markdown]
# **Exemplo 9.9:** Exemplo de gráficos de campos gradiente (campo vetorial) associado a uma função de duas variáveis (campo escalar).

# %%
f1 = lambda x,y: x**2+y**2
f2 = lambda x,y: x**2-y**2
f3 = lambda x,y: x**4+y**4-4*x*y+1

# %%
xi, yi = np.meshgrid(np.linspace(-5,5,201),
                     np.linspace(-5,5,201))

#criamos a figura e o subplot 3d
fig = plt.figure(figsize=(13,4))

ax = fig.add_subplot(131, projection='3d')
ax.plot_surface(xi, yi, f1(xi,yi))

ax = fig.add_subplot(132, projection='3d')
ax.plot_surface(xi, yi, f2(xi,yi))

ax = fig.add_subplot(133, projection='3d')
ax.plot_surface(xi, yi, f3(xi,yi))

plt.show()

# %%
xi, yi = np.meshgrid(np.linspace(-5,5,21),
                     np.linspace(-5,5,21))

#criamos a figura e o subplot 3d
fig = plt.figure(figsize=(13,4))

ax = fig.add_subplot(131)
u = np.gradient(f1(xi,yi))[1]
v = np.gradient(f1(xi,yi))[0]
plt.quiver(xi,yi,u,v, color='b')
plt.contour(xi, yi, f1(xi,yi),10, colors="r", linewidths=0.4)


ax = fig.add_subplot(132)
u = np.gradient(f2(xi,yi))[1]
v = np.gradient(f2(xi,yi))[0]
plt.quiver(xi,yi,u,v, color='b')
plt.contour(xi, yi, f2(xi,yi),10, colors="r", linewidths=0.4)


ax = fig.add_subplot(133)
u = np.gradient(f3(xi,yi))[1]
v = np.gradient(f3(xi,yi))[0]
plt.quiver(xi,yi,u,v, color='b')
xi, yi = np.meshgrid(np.linspace(-5,5), np.linspace(-5,5))
niveis = [-0.9, 0, 1, 2,10,50,100, 200, 400, 800]
plt.contour(xi, yi, f3(xi,yi),niveis, colors="r", linewidths=0.4)

plt.show()

# %% [markdown]
# ### Exercícios
#
# **1.** ([Fonte](https://integrada.minhabiblioteca.com.br/reader/books/9786555584103/pageid/307)) Utilize um computador para traçar a curva da equação vetorial dada. Escolha o domínio do parâmetro e ponto de vista de forma a revelar a verdadeira natureza da curva.
#
# a) $\mathbf{r}(t)=\langle\cos t \operatorname{sen} 2 t, \operatorname{sen} t \operatorname{sen} 2 t, \cos 2 t\rangle$
#
# b) $\mathbf{r}(t)=\left\langle t e^t, e^{-t}, t\right\rangle$
#
# c) $\mathbf{r}(t)=\left\langle\operatorname{sen} 3 t \cos t, \frac{1}{4} t, \operatorname{sen} 3 t \operatorname{sen} t\right\rangle$
#
# d) $\mathbf{r}(t)=\langle\cos (8 \cos t) \operatorname{sen} t, \operatorname{sen}(8 \cos t) \operatorname{sen} t, \cos t\rangle$
#
# e) $\mathbf{r}(t)=\langle\cos 2 t, \cos 3 t, \cos 4 t\rangle$
#
# **2.**. Trace a curva com equações paramétricas
# $$
# x=\operatorname{sen} t, \quad y=\operatorname{sen} 2 t, \quad z=\cos 4 t .
# $$
# Explique sua forma representando por gráficos suas projeções para os três planos coordenados.
#
# **3.** Trace a curva com equações paramétricas
# $$
# \begin{aligned}
# & x=(1+\cos 16 t) \cos t \\
# & y=(1+\cos 16 t) \operatorname{sen} t \\
# & z=1+\cos 16 t
# \end{aligned}
# $$
# Explique a aparência da curva, mostrando que ela está em um cone.
#
# **4.** Trace a curva com equações paramétricas
# $$
# \begin{aligned}
# & x=\sqrt{1-0,25 \cos ^2 10 t} \cos t \\
# & y=\sqrt{1-0,25 \cos ^2 10 t} \operatorname{sen} t \\
# & z=0,5 \cos 10 t
# \end{aligned}
# $$
# Explique a aparência da curva, mostrando que ela está em uma esfera.

# %% [markdown]
# **5.** Determine a função vetorial que representa a curva obtida pela intersecção das duas superficies.
#
# a) O cilindro de $x^2+y^2=4$ e a superfície $z=x y$
#
# b) O cone $z=\sqrt{x^2+y^2}$ e o plano $z=1+y$
#
# c) O paraboloide $z=4 x^2+y^2$ e o cilindro parabólico $y=x^2$
#
# d) A hipérbole $z=x^2-y^2$ e o cilindro $x^2+y^2=1$
#
# e) O semielipsoide $x^2+y^2+4 z^2=4, y \geq 0$, e o cilindro $x^2+z^2=1$

# %% [markdown]
# **6.** Plote os campos vetoriais dados

# %% [markdown]
# a) $\mathbf{F}(x, y)=-\frac{1}{2} \mathbf{i}+(y-x) \mathbf{j}$
#
# b) $\mathbf{F}(x, y)=y \mathbf{i}+(x+y) \mathbf{j}$
#
# c) $\mathbf{F}(x, y)=\frac{y \mathbf{i}+x \mathbf{j}}{\sqrt{x^2+y^2}}$
#
# d) $\mathbf{F}(x, y)=\frac{y \mathbf{i}-x \mathbf{j}}{\sqrt{x^2+y^2}}$
#
# e) $\mathbf{F}(x, y)=\langle y, y+2\rangle $
#
# f) $\mathbf{F}(x, y)=\langle\operatorname{sen} y, \cos x\rangle $
#
# g) $\mathbf{F}(x, y)=\langle\cos (x+y), x\rangle$
#
# h) $\mathbf{F}(x, y, z)=\langle\operatorname{sen} y, \cos x, xz^2\rangle$
#
# i) $\mathbf{F}(x, y, z)=\langle\cos (x+y), zx, zy\rangle$

# %% [markdown]
# **7.** Determine $\nabla f$, o campo vetorial gradiente de $f$.
#
# a) $f(x, y)=y \operatorname{sen}(x y)$
#
# b) $f(s, t)=\sqrt{2 s+3 t}$
#
# c) $f(x, y, z)=\sqrt{x^2+y^2+z^2}$
#
# d) $f(x, y, z)=x^2 y e^{y / z}$

# %%
fig = plt.figure(figsize=(4,3))
x = np.linspace(-5,5,20)
y = np.linspace(-5,5,20)
xi,yi = np.meshgrid(x,y)

u = np.sin(xi+yi)
v = xi
norm = np.sqrt(u**2+v**2)
#plt.streamplot(xi,yi,u,v)
plt.xlabel("x")
plt.ylabel("y")
plt.quiver(xi,yi,u/norm,v/norm)
plt.show()

# %%
#cria a figura
# %matplotlib inline
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')

# cilindro - coordenadas cilindricas
#t,z = np.meshgrid(np.linspace(0,2*np.pi,36), np.linspace(0,5,20))
#x = np.cos(t)
#y = np.sin(t)
#ax.plot_wireframe(x, y, z, lw=0.2, color='k')

# superficie
#x,y = np.meshgrid(np.linspace(-1,1,20), np.linspace(-1,1,20))
#z = x*y
#ax.plot_wireframe(x, y, z, lw=0.2, color='k')

t = np.linspace(0,2*np.pi,72)
x = np.cos(t)
y = 0.5*np.sin(t)
z = 2*np.cos(t)*np.sin(t)
ax.plot(x, y, z, lw=1, color='r')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
# Out:
# (-1.0, 1.0)
